# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations. 
lats = np.random.uniform(low = -90.000, high = 90.000, size=2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 780

# %%
import requests
# Import the API key.
from config import weather_api_key
requests.__version__
# Out:
# '2.24.0'

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=6f69822185a74de01c8ce51262da1787

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                         "Weather Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint anthony
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | kimbe
# Processing Record 5 of Set 1 | takaka
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | saint-philippe
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | mar del plata
# Processing Record 10 of Set 1 | brufut
# Processing Record 11 of Set 1 | grindavik
# Processing Record 12 of Set 1 | iquique
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | chifeng
# Processing Record 16 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | daxian
# City not found. Skipping...
# Processing Record 20 of Set 1 | cayenne
# Processing Record 21 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 1 | barrhead
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 25 of Set 1 | te anau
# Processing Record 26 of Set 1 | hithadhoo
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | nanortalik
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | khatanga
# Processing Record 32 of Set 1 | faanui
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | hovd
# Processing Record 35 of Set 1 | kruisfontein
# Processing Record 36 of Set 1 | yumen
# Processing Record 37 of Set 1 | esperance
# Processing Record 38 of Set 1 | port-gentil
# Processing Record 39 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 40 of Set 1 | clyde river
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | vao
# Processing Record 43 of Set 1 | talas
# Processing Record 44 of Set 1 | san ramon
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | gunjur
# Processing Record 47 of Set 1 | tuktoyaktuk
# Processing Record 48 of Set 1 | khandyga
# Processing Record 49 of Set 1 | upington
# Processing Record 50 of Set 1 | bandarbeyla
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | touros
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | ribeira grande
# Processing Record 6 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 7 of Set 2 | saint george
# Processing Record 8 of Set 2 | kodiak
# Processing Record 9 of Set 2 | dundee
# Processing Record 10 of Set 2 | katsuura
# Processing Record 11 of Set 2 | severo-kurilsk
# Processing Record 12 of Set 2 | presidencia roque saenz pena
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | ampanihy
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | fria
# Processing Record 17 of Set 2 | kismayo
# Processing Record 18 of Set 2 | rocha
# Processing Record 19 of Set 2 | birjand
# Processing Record 20 of Set 2 | kavieng
# Processing Record 21 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 2 | souillac
# Processing Record 23 of Set 2 | zyryanka
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | lensk
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | chikoy
# City not found. Skipping...
# Processing Record 29 of Set 2 | kansanshi
# Processing Record 30 of Set 2 | douentza
# Processing Record 31 of Set 2 | tura
# Processing Record 32 of Set 2 | wagar
# Processing Record 33 of Set 2 | miri
# Processing Record 34 of Set 2 | kharitonovo
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | dingli
# Processing Record 37 of Set 2 | sitka
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | kiama
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | avarua
# Processing Record 42 of Set 2 | west bay
# Processing Record 43 of Set 2 | solhan
# Processing Record 44 of Set 2 | chuy
# Processing Record 45 of Set 2 | proddatur
# Processing Record 46 of Set 2 | kahului
# Processing Record 47 of Set 2 | red bluff
# Processing Record 48 of Set 2 | dingle
# Processing Record 49 of Set 2 | barrow
# Processing Record 50 of Set 2 | gimli
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | iqaluit
# Processing Record 3 of Set 3 | lompoc
# Processing Record 4 of Set 3 | udachnyy
# Processing Record 5 of Set 3 | mingguang
# Processing Record 6 of Set 3 | upernavik
# Processing Record 7 of Set 3 | turangi
# Processing Record 8 of Set 3 | hilo
# Processing Record 9 of Set 3 | luderitz
# Processing Record 10 of Set 3 | port alfred
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | spring hill
# Processing Record 14 of Set 3 | talnakh
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | calama
# Processing Record 17 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 18 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 3 | shimoda
# Processing Record 20 of Set 3 | port macquarie
# Processing Record 21 of Set 3 | libenge
# Processing Record 22 of Set 3 | kawalu
# Processing Record 23 of Set 3 | dayong
# Processing Record 24 of Set 3 | port elizabeth
# Processing Record 25 of Set 3 | new norfolk
# Processing Record 26 of Set 3 | taber
# Processing Record 27 of Set 3 | butaritari
# Processing Record 28 of Set 3 | vaini
# Processing Record 29 of Set 3 | lavrentiya
# Processing Record 30 of Set 3 | dawlatabad
# Processing Record 31 of Set 3 | syktyvkar
# Processing Record 32 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 33 of Set 3 | abalak
# Processing Record 34 of Set 3 | castro
# Processing Record 35 of Set 3 | airai
# Processing Record 36 of Set 3 | bambous virieux
# Processing Record 37 of Set 3 | varhaug
# Processing Record 38 of Set 3 | ahipara
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | port hueneme
# Processing Record 41 of Set 3 | guhagar
# Processing Record 42 of Set 3 | stephenville
# Processing Record 43 of Set 3 | sao jose da coroa grande
# Processing Record 44 of Set 3 | puerto escondido
# Processing Record 45 of Set 3 | tuatapere
# Processing Record 46 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 3 | panzhihua
# Processing Record 48 of Set 3 | athens
# Processing Record 49 of Set 3 | rath
# Processing Record 50 of Set 3 | oranjestad
# Processing Record 1 of Set 4 | kavaratti
# Processing Record 2 of Set 4 | nguruka
# Processing Record 3 of Set 4 | lucea
# Processing Record 4 of Set 4 | hasaki
# Processing Record 5 of Set 4 | alofi
# Processing Record 6 of Set 4 | jiuquan
# Processing Record 7 of Set 4 | orange cove
# Processing Record 8 of Set 4 | jining
# Processing Record 9 of Set 4 | paita
# Processing Record 10 of Set 4 | albion
# Processing Record 11 of Set 4 | qaanaaq
# Processing Record 12 of Set 4 | matay
# Processing Record 13 of Set 4 | pevek
# Processing Record 14 of Set 4 | senador guiomard
# Processing Record 15 of Set 4 | zhezkazgan
# Processing Record 16 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 4 | khasan
# Processing Record 18 of Set 4 | ulaanbaatar
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 4 | la ronge
# Processing Record 22 of Set 4 | lebedinyy
# Processing Record 23 of Set 4 | provideniya
# Processing Record 24 of Set 4 | mayumba
# Processing Record 25 of Set 4 | fortuna
# Processing Record 26 of Set 4 | mahibadhoo
# Processing Record 27 of Set 4 | norman wells
# Processing Record 28 of Set 4 | pacific grove
# Processing Record 29 of Set 4 | columbus
# Processing Record 30 of Set 4 | tubuala
# Processing Record 31 of Set 4 | sawakin
# Processing Record 32 of Set 4 | kailua
# Processing Record 33 of Set 4 | skagen
# Processing Record 34 of Set 4 | pisco
# Processing Record 35 of Set 4 | great bend
# Processing Record 36 of Set 4 | tasiilaq
# Processing Record 37 of Set 4 | jumla
# Processing Record 38 of Set 4 | quelimane
# Processing Record 39 of Set 4 | pangnirtung
# Processing Record 40 of Set 4 | vila velha
# Processing Record 41 of Set 4 | birin
# Processing Record 42 of Set 4 | arraial do cabo
# Processing Record 43 of Set 4 | coalville
# Processing Record 44 of Set 4 | narsaq
# Processing Record 45 of Set 4 | meulaboh
# Processing Record 46 of Set 4 | gari
# Processing Record 47 of Set 4 | salalah
# Processing Record 48 of Set 4 | tiznit
# Processing Record 49 of Set 4 | stavern
# Processing Record 50 of Set 4 | afgoye
# City not found. Skipping...
# Processing Record 1 of Set 5 | moosomin
# Processing Record 2 of Set 5 | mahebourg
# Processing Record 3 of Set 5 | samarai
# Processing Record 4 of Set 5 | tabou
# Processing Record 5 of Set 5 | caravelas
# Processing Record 6 of Set 5 | port hedland
# Processing Record 7 of Set 5 | berlevag
# Processing Record 8 of Set 5 | fenoarivo
# Processing Record 9 of Set 5 | bambanglipuro
# Processing Record 10 of Set 5 | camacha
# Processing Record 11 of Set 5 | georgetown
# Processing Record 12 of Set 5 | college
# Processing Record 13 of Set 5 | warmbad
# Processing Record 14 of Set 5 | fort nelson
# Processing Record 15 of Set 5 | ouadda
# Processing Record 16 of Set 5 | lasa
# Processing Record 17 of Set 5 | ambanja
# Processing Record 18 of Set 5 | nago
# Processing Record 19 of Set 5 | carrollton
# Processing Record 20 of Set 5 | vrangel
# Processing Record 21 of Set 5 | rubizhne
# Processing Record 22 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 5 | shujalpur
# Processing Record 24 of Set 5 | dauphin
# Processing Record 25 of Set 5 | ardesen
# Processing Record 26 of Set 5 | carndonagh
# Processing Record 27 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 5 | pandan
# Processing Record 29 of Set 5 | bethel
# Processing Record 30 of Set 5 | guerrero negro
# Processing Record 31 of Set 5 | carnarvon
# Processing Record 32 of Set 5 | baykit
# Processing Record 33 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 34 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 5 | nome
# Processing Record 36 of Set 5 | umm kaddadah
# Processing Record 37 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 5 | longyearbyen
# Processing Record 39 of Set 5 | sistranda
# Processing Record 40 of Set 5 | raudeberg
# Processing Record 41 of Set 5 | basoko
# Processing Record 42 of Set 5 | cockburn town
# Processing Record 43 of Set 5 | flinders
# Processing Record 44 of Set 5 | lyngseidet
# Processing Record 45 of Set 5 | alexandria
# Processing Record 46 of Set 5 | kumluca
# Processing Record 47 of Set 5 | billings
# Processing Record 48 of Set 5 | kachug
# Processing Record 49 of Set 5 | alekseyevka
# Processing Record 50 of Set 5 | rio grande
# Processing Record 1 of Set 6 | jinja
# Processing Record 2 of Set 6 | abejorral
# Processing Record 3 of Set 6 | zabol
# Processing Record 4 of Set 6 | juneau
# Processing Record 5 of Set 6 | banepa
# Processing Record 6 of Set 6 | nelson bay
# Processing Record 7 of Set 6 | port blair
# Processing Record 8 of Set 6 | lerwick
# Processing Record 9 of Set 6 | mayo
# Processing Record 10 of Set 6 | ruteng
# Processing Record 11 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 12 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 6 | olafsvik
# Processing Record 15 of Set 6 | kibaya
# Processing Record 16 of Set 6 | komsomolskiy
# Processing Record 17 of Set 6 | riyadh
# Processing Record 18 of Set 6 | grand gaube
# Processing Record 19 of Set 6 | victor harbor
# Processing Record 20 of Set 6 | paraiso
# Processing Record 21 of Set 6 | necochea
# Processing Record 22 of Set 6 | lobez
# Processing Record 23 of Set 6 | pittsburg
# Processing Record 24 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 6 | itaqui
# Processing Record 26 of Set 6 | goderich
# Processing Record 27 of Set 6 | darovskoy
# Processing Record 28 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 6 | ekhabi
# Processing Record 30 of Set 6 | cabo san lucas
# Processing Record 31 of Set 6 | veraval
# Processing Record 32 of Set 6 | tibacuy
# Processing Record 33 of Set 6 | birao
# Processing Record 34 of Set 6 | san cristobal
# Processing Record 35 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 6 | crab hill
# City not found. Skipping...
# Processing Record 37 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 6 | guelengdeng
# City not found. Skipping...
# Processing Record 39 of Set 6 | dunedin
# Processing Record 40 of Set 6 | portland
# Processing Record 41 of Set 6 | muborak
# Processing Record 42 of Set 6 | yichun
# Processing Record 43 of Set 6 | pioner
# Processing Record 44 of Set 6 | dikson
# Processing Record 45 of Set 6 | belmonte
# Processing Record 46 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 47 of Set 6 | guozhen
# Processing Record 48 of Set 6 | kalisz
# Processing Record 49 of Set 6 | richards bay
# Processing Record 50 of Set 6 | oranjemund
# Processing Record 1 of Set 7 | ossora
# Processing Record 2 of Set 7 | mehamn
# Processing Record 3 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 7 | yinchuan
# Processing Record 5 of Set 7 | namatanai
# Processing Record 6 of Set 7 | lakes entrance
# Processing Record 7 of Set 7 | ancud
# Processing Record 8 of Set 7 | mampong
# Processing Record 9 of Set 7 | san patricio
# Processing Record 10 of Set 7 | broken hill
# Processing Record 11 of Set 7 | gravelbourg
# Processing Record 12 of Set 7 | husavik
# Processing Record 13 of Set 7 | ormara
# Processing Record 14 of Set 7 | longonjo
# Processing Record 15 of Set 7 | comodoro rivadavia
# Processing Record 16 of Set 7 | kungurtug
# Processing Record 17 of Set 7 | hobe sound
# Processing Record 18 of Set 7 | geraldton
# Processing Record 19 of Set 7 | tommot
# Processing Record 20 of Set 7 | kieta
# Processing Record 21 of Set 7 | makakilo city
# Processing Record 22 of Set 7 | jalu
# Processing Record 23 of Set 7 | coquimbo
# Processing Record 24 of Set 7 | vagamo
# Processing Record 25 of Set 7 | kaitangata
# Processing Record 26 of Set 7 | volksrust
# Processing Record 27 of Set 7 | kasempa
# Processing Record 28 of Set 7 | pavilosta
# Processing Record 29 of Set 7 | esmeraldas
# Processing Record 30 of Set 7 | kamaishi
# Processing Record 31 of Set 7 | nemuro
# Processing Record 32 of Set 7 | marzuq
# Processing Record 33 of Set 7 | mount gambier
# Processing Record 34 of Set 7 | bud
# Processing Record 35 of Set 7 | potot
# Processing Record 36 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 37 of Set 7 | banamba
# Processing Record 38 of Set 7 | araceli
# Processing Record 39 of Set 7 | sabang
# Processing Record 40 of Set 7 | yegros
# Processing Record 41 of Set 7 | hamilton
# Processing Record 42 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 7 | opuwo
# Processing Record 44 of Set 7 | shu
# Processing Record 45 of Set 7 | leningradskiy
# Processing Record 46 of Set 7 | sao joao da barra
# Processing Record 47 of Set 7 | margate
# Processing Record 48 of Set 7 | pergamino
# Processing Record 49 of Set 7 | keffi
# Processing Record 50 of Set 7 | lagdo
# Processing Record 1 of Set 8 | groningen
# Processing Record 2 of Set 8 | nyuksenitsa
# Processing Record 3 of Set 8 | karratha
# Processing Record 4 of Set 8 | nara
# Processing Record 5 of Set 8 | kapuskasing
# Processing Record 6 of Set 8 | namibe
# Processing Record 7 of Set 8 | livingston
# Processing Record 8 of Set 8 | saldanha
# Processing Record 9 of Set 8 | ontario
# Processing Record 10 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 8 | sovetskiy
# Processing Record 12 of Set 8 | ketchikan
# Processing Record 13 of Set 8 | muisne
# Processing Record 14 of Set 8 | soe
# Processing Record 15 of Set 8 | katangli
# Processing Record 16 of Set 8 | kaduy
# Processing Record 17 of Set 8 | kondinskoye
# Processing Record 18 of Set 8 | agadez
# Processing Record 19 of Set 8 | myitkyina
# Processing Record 20 of Set 8 | litein
# Processing Record 21 of Set 8 | westport
# Processing Record 22 of Set 8 | murdochville
# Processing Record 23 of Set 8 | inhambane
# Processing Record 24 of Set 8 | maner
# Processing Record 25 of Set 8 | zhangye
# Processing Record 26 of Set 8 | pionerskiy
# Processing Record 27 of Set 8 | buenos aires
# Processing Record 28 of Set 8 | paamiut
# Processing Record 29 of Set 8 | along
# Processing Record 30 of Set 8 | naranjal
# Processing Record 31 of Set 8 | ilinskoye-khovanskoye
# Processing Record 32 of Set 8 | morondava
# Processing Record 33 of Set 8 | aldan
# Processing Record 34 of Set 8 | fujin
# Processing Record 35 of Set 8 | tacuarembo
# Processing Record 36 of Set 8 | portlethen
# Processing Record 37 of Set 8 | boa vista
# Processing Record 38 of Set 8 | nurota
# Processing Record 39 of Set 8 | labrea
# Processing Record 40 of Set 8 | murfreesboro
# Processing Record 41 of Set 8 | buchanan
# Processing Record 42 of Set 8 | san quintin
# Processing Record 43 of Set 8 | shubarkuduk
# Processing Record 44 of Set 8 | sao filipe
# Processing Record 45 of Set 8 | koumac
# Processing Record 46 of Set 8 | tabuk
# Processing Record 47 of Set 8 | codrington
# Processing Record 48 of Set 8 | guane
# Processing Record 49 of Set 8 | morros
# Processing Record 50 of Set 8 | yerbogachen
# Processing Record 1 of Set 9 | inirida
# Processing Record 2 of Set 9 | lata
# Processing Record 3 of Set 9 | norman
# Processing Record 4 of Set 9 | yulara
# Processing Record 5 of Set 9 | shitkino
# Processing Record 6 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 9 | nishihara
# Processing Record 8 of Set 9 | zanjan
# Processing Record 9 of Set 9 | puerto del rosario
# Processing Record 10 of Set 9 | atchison
# Processing Record 11 of Set 9 | boyolangu
# Processing Record 12 of Set 9 | tezu
# Processing Record 13 of Set 9 | mariental
# Processing Record 14 of Set 9 | fare
# Processing Record 15 of Set 9 | bengkulu
# Processing Record 16 of Set 9 | nesbyen
# Processing Record 17 of Set 9 | lusaka
# Processing Record 18 of Set 9 | vostok
# Processing Record 19 of Set 9 | wasilla
# Processing Record 20 of Set 9 | bantry
# Processing Record 21 of Set 9 | xinmin
# Processing Record 22 of Set 9 | porto novo
# Processing Record 23 of Set 9 | taraclia
# Processing Record 24 of Set 9 | palana
# Processing Record 25 of Set 9 | aklavik
# Processing Record 26 of Set 9 | silifke
# Processing Record 27 of Set 9 | espanola
# Processing Record 28 of Set 9 | thompson
# Processing Record 29 of Set 9 | tadine
# Processing Record 30 of Set 9 | santiago del estero
# Processing Record 31 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 9 | araouane
# Processing Record 33 of Set 9 | xining
# Processing Record 34 of Set 9 | beringovskiy
# Processing Record 35 of Set 9 | shuangcheng
# Processing Record 36 of Set 9 | torbay
# Processing Record 37 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 9 | port shepstone
# Processing Record 39 of Set 9 | kalaleh
# Processing Record 40 of Set 9 | gasa
# Processing Record 41 of Set 9 | don matias
# Processing Record 42 of Set 9 | isangel
# Processing Record 43 of Set 9 | adre
# Processing Record 44 of Set 9 | nouadhibou
# Processing Record 45 of Set 9 | saint-augustin
# Processing Record 46 of Set 9 | kearney
# Processing Record 47 of Set 9 | cairns
# Processing Record 48 of Set 9 | tarauaca
# Processing Record 49 of Set 9 | guangyuan
# Processing Record 50 of Set 9 | palm valley
# Processing Record 1 of Set 10 | kaeo
# Processing Record 2 of Set 10 | kathu
# Processing Record 3 of Set 10 | evensk
# Processing Record 4 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 5 of Set 10 | tokur
# Processing Record 6 of Set 10 | kitimat
# Processing Record 7 of Set 10 | fairbanks
# Processing Record 8 of Set 10 | dukat
# Processing Record 9 of Set 10 | lempaala
# Processing Record 10 of Set 10 | miracema
# Processing Record 11 of Set 10 | miles city
# Processing Record 12 of Set 10 | vila
# Processing Record 13 of Set 10 | sobolevo
# Processing Record 14 of Set 10 | masterton
# Processing Record 15 of Set 10 | bismarck
# Processing Record 16 of Set 10 | guajara-mirim
# City not found. Skipping...
# Processing Record 17 of Set 10 | port hawkesbury
# Processing Record 18 of Set 10 | satun
# Processing Record 19 of Set 10 | bathsheba
# Processing Record 20 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 10 | nuuk
# Processing Record 22 of Set 10 | jinchang
# Processing Record 23 of Set 10 | naze
# Processing Record 24 of Set 10 | umm lajj
# Processing Record 25 of Set 10 | puerto penasco
# Processing Record 26 of Set 10 | mandera
# Processing Record 27 of Set 10 | tonstad
# Processing Record 28 of Set 10 | high level
# Processing Record 29 of Set 10 | changji
# Processing Record 30 of Set 10 | andenes
# Processing Record 31 of Set 10 | daru
# Processing Record 32 of Set 10 | kangaatsiaq
# Processing Record 33 of Set 10 | alytus
# Processing Record 34 of Set 10 | lakatoro
# Processing Record 35 of Set 10 | morant bay
# Processing Record 36 of Set 10 | sao luis
# Processing Record 37 of Set 10 | crotone
# Processing Record 38 of Set 10 | adilabad
# Processing Record 39 of Set 10 | rawson
# Processing Record 40 of Set 10 | vardo
# Processing Record 41 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 10 | zalantun
# Processing Record 43 of Set 10 | sena madureira
# Processing Record 44 of Set 10 | menongue
# Processing Record 45 of Set 10 | manaus
# Processing Record 46 of Set 10 | hurricane
# Processing Record 47 of Set 10 | natal
# Processing Record 48 of Set 10 | sao luiz gonzaga
# Processing Record 49 of Set 10 | tsiroanomandidy
# Processing Record 50 of Set 10 | balkanabat
# Processing Record 1 of Set 11 | arman
# Processing Record 2 of Set 11 | serenje
# Processing Record 3 of Set 11 | razole
# Processing Record 4 of Set 11 | fort-shevchenko
# Processing Record 5 of Set 11 | vila franca do campo
# Processing Record 6 of Set 11 | cabedelo
# Processing Record 7 of Set 11 | hailey
# Processing Record 8 of Set 11 | gbarnga
# Processing Record 9 of Set 11 | sabha
# Processing Record 10 of Set 11 | ulaangom
# Processing Record 11 of Set 11 | pangody
# Processing Record 12 of Set 11 | chengde
# Processing Record 13 of Set 11 | zheleznodorozhnyy
# Processing Record 14 of Set 11 | cap malheureux
# Processing Record 15 of Set 11 | marsh harbour
# Processing Record 16 of Set 11 | hofn
# Processing Record 17 of Set 11 | kamenka
# Processing Record 18 of Set 11 | arua
# Processing Record 19 of Set 11 | aqtobe
# Processing Record 20 of Set 11 | buckeye
# Processing Record 21 of Set 11 | angoche
# Processing Record 22 of Set 11 | kushiro
# Processing Record 23 of Set 11 | binzhou
# Processing Record 24 of Set 11 | teacapan
# Processing Record 25 of Set 11 | alta
# Processing Record 26 of Set 11 | matamoros
# Processing Record 27 of Set 11 | nurlat
# Processing Record 28 of Set 11 | faya
# Processing Record 29 of Set 11 | oktyabrskiy
# Processing Record 30 of Set 11 | ust-ishim
# Processing Record 31 of Set 11 | karaton
# Processing Record 32 of Set 11 | hami
# Processing Record 33 of Set 11 | ecroignard
# Processing Record 34 of Set 11 | texarkana
# Processing Record 35 of Set 11 | port hardy
# Processing Record 36 of Set 11 | apache junction
# Processing Record 37 of Set 11 | sokol
# Processing Record 38 of Set 11 | pousat
# City not found. Skipping...
# Processing Record 39 of Set 11 | nehe
# Processing Record 40 of Set 11 | baragua
# Processing Record 41 of Set 11 | conyers
# Processing Record 42 of Set 11 | warrnambool
# Processing Record 43 of Set 11 | banff
# Processing Record 44 of Set 11 | amahai
# Processing Record 45 of Set 11 | begoro
# Processing Record 46 of Set 11 | sitangkai
# Processing Record 47 of Set 11 | vestmannaeyjar
# Processing Record 48 of Set 11 | rosetta
# Processing Record 49 of Set 11 | yeletskiy
# City not found. Skipping...
# Processing Record 50 of Set 11 | port lincoln
# Processing Record 1 of Set 12 | wamba
# Processing Record 2 of Set 12 | vagur
# Processing Record 3 of Set 12 | gat
# Processing Record 4 of Set 12 | bogotol
# Processing Record 5 of Set 12 | chicama
# Processing Record 6 of Set 12 | nantucket
# Processing Record 7 of Set 12 | alice springs
# Processing Record 8 of Set 12 | talcahuano
# Processing Record 9 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 10 of Set 12 | havre-saint-pierre
# Processing Record 11 of Set 12 | dinguiraye
# Processing Record 12 of Set 12 | buala
# Processing Record 13 of Set 12 | orlik
# Processing Record 14 of Set 12 | fairview
# Processing Record 15 of Set 12 | suntar
# Processing Record 16 of Set 12 | uzhur
# Processing Record 17 of Set 12 | henties bay
# Processing Record 18 of Set 12 | burica
# City not found. Skipping...
# Processing Record 19 of Set 12 | mabaruma
# Processing Record 20 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 21 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 12 | saint-leu
# Processing Record 23 of Set 12 | sur
# Processing Record 24 of Set 12 | santa cruz
# Processing Record 25 of Set 12 | pedernales
# Processing Record 26 of Set 12 | martapura
# Processing Record 27 of Set 12 | panguna
# Processing Record 28 of Set 12 | neiafu
# Processing Record 29 of Set 12 | makubetsu
# Processing Record 30 of Set 12 | skagastrond
# City not found. Skipping...
# Processing Record 31 of Set 12 | constancia
# Processing Record 32 of Set 12 | beira
# Processing Record 33 of Set 12 | monte azul
# Processing Record 34 of Set 12 | norsup
# Processing Record 35 of Set 12 | wanning
# Processing Record 36 of Set 12 | axim
# Processing Record 37 of Set 12 | klyuchi
# Processing Record 38 of Set 12 | sahibganj
# Processing Record 39 of Set 12 | takoradi
# Processing Record 40 of Set 12 | emba
# Processing Record 41 of Set 12 | ca mau
# Processing Record 42 of Set 12 | hervey bay
# Processing Record 43 of Set 12 | seaford
# Processing Record 44 of Set 12 | amapa
# Processing Record 45 of Set 12 | nagato
# Processing Record 46 of Set 12 | dolores
# Processing Record 47 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 12 | yanam
# Processing Record 49 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 50 of Set 12 | klaksvik
# Processing Record 1 of Set 13 | asau
# Processing Record 2 of Set 13 | novoagansk
# Processing Record 3 of Set 13 | saurimo
# Processing Record 4 of Set 13 | barcelos
# Processing Record 5 of Set 13 | eskil
# Processing Record 6 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 13 | sinaloa
# Processing Record 8 of Set 13 | noumea
# Processing Record 9 of Set 13 | voskresenskoye
# Processing Record 10 of Set 13 | johi
# Processing Record 11 of Set 13 | celestun
# Processing Record 12 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 13 of Set 13 | dovolnoye
# Processing Record 14 of Set 13 | hare bay
# Processing Record 15 of Set 13 | griffith
# Processing Record 16 of Set 13 | bereslavka
# Processing Record 17 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 13 | lorengau
# Processing Record 19 of Set 13 | antofagasta
# Processing Record 20 of Set 13 | langxiang
# Processing Record 21 of Set 13 | akdepe
# Processing Record 22 of Set 13 | clarence town
# Processing Record 23 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 24 of Set 13 | bonnyville
# Processing Record 25 of Set 13 | pyaozerskiy
# Processing Record 26 of Set 13 | wuning
# Processing Record 27 of Set 13 | garmsar
# Processing Record 28 of Set 13 | auki
# Processing Record 29 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 30 of Set 13 | conde
# Processing Record 31 of Set 13 | phu ly
# Processing Record 32 of Set 13 | bucksport
# Processing Record 33 of Set 13 | ciudad bolivar
# Processing Record 34 of Set 13 | areosa
# Processing Record 35 of Set 13 | urucui
# Processing Record 36 of Set 13 | magadan
# Processing Record 37 of Set 13 | mackay
# Processing Record 38 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 39 of Set 13 | eureka
# Processing Record 40 of Set 13 | montecristi
# Processing Record 41 of Set 13 | yei
# Processing Record 42 of Set 13 | sibi
# Processing Record 43 of Set 13 | republic
# Processing Record 44 of Set 13 | launceston
# Processing Record 45 of Set 13 | quetzaltepec
# City not found. Skipping...
# Processing Record 46 of Set 13 | assare
# Processing Record 47 of Set 13 | sayyan
# Processing Record 48 of Set 13 | manono
# Processing Record 49 of Set 13 | racine
# Processing Record 50 of Set 13 | yar-sale
# Processing Record 1 of Set 14 | sorland
# Processing Record 2 of Set 14 | lieksa
# Processing Record 3 of Set 14 | puri
# Processing Record 4 of Set 14 | bayangol
# Processing Record 5 of Set 14 | suluq
# Processing Record 6 of Set 14 | agirish
# Processing Record 7 of Set 14 | taoudenni
# Processing Record 8 of Set 14 | pfullendorf
# Processing Record 9 of Set 14 | nyimba
# Processing Record 10 of Set 14 | terney
# Processing Record 11 of Set 14 | ilebo
# Processing Record 12 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 14 | cervo
# Processing Record 14 of Set 14 | vanimo
# Processing Record 15 of Set 14 | we
# City not found. Skipping...
# Processing Record 16 of Set 14 | high rock
# Processing Record 17 of Set 14 | onojo
# Processing Record 18 of Set 14 | mao
# Processing Record 19 of Set 14 | hobyo
# Processing Record 20 of Set 14 | almeria
# Processing Record 21 of Set 14 | fukue
# Processing Record 22 of Set 14 | america dourada
# Processing Record 23 of Set 14 | maniitsoq
# Processing Record 24 of Set 14 | arkhangelsk
# Processing Record 25 of Set 14 | deputatskiy
# Processing Record 26 of Set 14 | miraflores
# Processing Record 27 of Set 14 | bonaventure
# Processing Record 28 of Set 14 | maragogi
# Processing Record 29 of Set 14 | coracora
# Processing Record 30 of Set 14 | peoria
# Processing Record 31 of Set 14 | sarakhs
# Processing Record 32 of Set 14 | bealanana
# Processing Record 33 of Set 14 | ban nahin
# Processing Record 34 of Set 14 | lapy
# Processing Record 35 of Set 14 | svobodnyy
# Processing Record 36 of Set 14 | sao felix do xingu
# Processing Record 37 of Set 14 | ostrovnoy
# Processing Record 38 of Set 14 | paducah
# Processing Record 39 of Set 14 | mitsamiouli
# Processing Record 40 of Set 14 | roma
# Processing Record 41 of Set 14 | porbandar
# Processing Record 42 of Set 14 | imbituba
# Processing Record 43 of Set 14 | valkeala
# Processing Record 44 of Set 14 | urengoy
# Processing Record 45 of Set 14 | vaitape
# Processing Record 46 of Set 14 | egvekinot
# Processing Record 47 of Set 14 | tartagal
# Processing Record 48 of Set 14 | qianan
# Processing Record 49 of Set 14 | worthington
# Processing Record 50 of Set 14 | bundaberg
# Processing Record 1 of Set 15 | waddan
# Processing Record 2 of Set 15 | kashi
# Processing Record 3 of Set 15 | biu
# Processing Record 4 of Set 15 | santa rosalia
# Processing Record 5 of Set 15 | jales
# Processing Record 6 of Set 15 | lac du bonnet
# Processing Record 7 of Set 15 | marfino
# Processing Record 8 of Set 15 | dubreka
# Processing Record 9 of Set 15 | yambio
# Processing Record 10 of Set 15 | ban phai
# Processing Record 11 of Set 15 | olinda
# Processing Record 12 of Set 15 | okotoks
# Processing Record 13 of Set 15 | temiscaming
# Processing Record 14 of Set 15 | bowen
# Processing Record 15 of Set 15 | muravlenko
# Processing Record 16 of Set 15 | ambovombe
# Processing Record 17 of Set 15 | yenagoa
# Processing Record 18 of Set 15 | san policarpo
# Processing Record 19 of Set 15 | mana
# Processing Record 20 of Set 15 | poronaysk
# Processing Record 21 of Set 15 | luba
# Processing Record 22 of Set 15 | bambari
# Processing Record 23 of Set 15 | zhanaozen
# Processing Record 24 of Set 15 | alyangula
# Processing Record 25 of Set 15 | moorhead
# Processing Record 26 of Set 15 | mount isa
# Processing Record 27 of Set 15 | marsa matruh
# Processing Record 28 of Set 15 | kasongo-lunda
# Processing Record 29 of Set 15 | buta
# Processing Record 30 of Set 15 | bitburg
# Processing Record 31 of Set 15 | rennes
# Processing Record 32 of Set 15 | naukot
# Processing Record 33 of Set 15 | indian head
# Processing Record 34 of Set 15 | gua musang
# Processing Record 35 of Set 15 | calabozo
# Processing Record 36 of Set 15 | cassilandia
# Processing Record 37 of Set 15 | vertou
# Processing Record 38 of Set 15 | sisimiut
# Processing Record 39 of Set 15 | bandar-e anzali
# Processing Record 40 of Set 15 | los llanos de aridane
# Processing Record 41 of Set 15 | vysokogornyy
# Processing Record 42 of Set 15 | palmer
# Processing Record 43 of Set 15 | wattegama
# Processing Record 44 of Set 15 | rio gallegos
# Processing Record 45 of Set 15 | phibun mangsahan
# Processing Record 46 of Set 15 | loa janan
# Processing Record 47 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 15 | pahrump
# Processing Record 49 of Set 15 | chik
# Processing Record 50 of Set 15 | tromso
# Processing Record 1 of Set 16 | atar
# Processing Record 2 of Set 16 | banda aceh
# Processing Record 3 of Set 16 | kracheh
# City not found. Skipping...
# Processing Record 4 of Set 16 | taupo
# Processing Record 5 of Set 16 | upata
# Processing Record 6 of Set 16 | lokosovo
# Processing Record 7 of Set 16 | talara
# Processing Record 8 of Set 16 | champerico
# Processing Record 9 of Set 16 | rosarito
# Processing Record 10 of Set 16 | kandhla
# Processing Record 11 of Set 16 | pacifica
# Processing Record 12 of Set 16 | sevsk
# Processing Record 13 of Set 16 | batagay-alyta
# Processing Record 14 of Set 16 | coihaique
# Processing Record 15 of Set 16 | yirol
# City not found. Skipping...
# Processing Record 16 of Set 16 | todos santos
# Processing Record 17 of Set 16 | muroto
# Processing Record 18 of Set 16 | thouars
# Processing Record 19 of Set 16 | lichtenburg
# Processing Record 20 of Set 16 | beruni
# City not found. Skipping...
# Processing Record 21 of Set 16 | otyniya
# Processing Record 22 of Set 16 | bad langensalza
# Processing Record 23 of Set 16 | powell river
# Processing Record 24 of Set 16 | adelaide
# Processing Record 25 of Set 16 | oktyabrskoye
# Processing Record 26 of Set 16 | aktau
# Processing Record 27 of Set 16 | jejuri
# Processing Record 28 of Set 16 | kirakira
# Processing Record 29 of Set 16 | sloboda
# Processing Record 30 of Set 16 | dakar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 713

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Saint Anthony  45.0205  -93.2180     33.80        69          90
# 1      Nikolskoye  59.7035   30.7861     26.60        86          75
# 2         Rikitea -23.1203 -134.9692     79.25        62          29
# 3           Kimbe  -5.5502  150.1429     83.46        76          85
# 4          Takaka -40.8500  172.8000     66.00        79           0
# 5           Bluff -46.6000  168.3333     61.29        68          63
# 6  Saint-Philippe -21.3585   55.7679     80.60        74          20
# 7      Bredasdorp -34.5322   20.0403     63.00        83          99
# 8   Mar Del Plata -38.0023  -57.5575     64.40        68          75
# 9          Brufut  13.3814  -16.7518     78.80        38           0
#
#    Wind Speed Country                 Date Weather Description
# 0        9.22      US  2021-01-31 22:55:21     overcast clouds
# 1        6.71      RU  2021-01-31 22:55:22                snow
# 2        7.14      PF  2021-01-31 22:55:22    scattered clouds
# 3        6.31      PG  2021-01-31 22:55:22          light rain
# 4        3.00      NZ  2021-01-31 22:55:22           clear sky
# 5        3.69      NZ  2021-01-31 22:55:23       broken clouds
# 6       12.66      RE  2021-01-31 22:55:23          light rain
# 7        1.01      ZA  2021-01-31 22:55:23     overcast clouds
# 8       12.66      AR  2021-01-31 22:53:39       broken clouds
# 9       12.15      GM  2021-01-31 22:55:23           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
