# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID            City Country  Max Temp Weather Description      Lat  \
# 0        2         Rikitea      PF     79.25    scattered clouds -23.1203
# 1        3           Kimbe      PG     83.46          light rain  -5.5502
# 2        6  Saint-Philippe      RE     80.60          light rain -21.3585
# 3        9          Brufut      GM     78.80           clear sky  13.3814
# 4       11         Iquique      CL     73.40           clear sky -20.2208
#
#         Lng                          Hotel Name
# 0 -134.9692                      Pension Maro'i
# 1  150.1429                     Kimbe Bay Hotel
# 2   55.7679        Chambres d'hôte "La Trinité"
# 3  -16.7518  Sheraton Gambia Hotel Resort & Spa
# 4  -70.1431         Backpacker`s Hostel Iquique

# %%
Brazil_itinerary_df = vacation_df.loc[(vacation_df['Country'] =='BR')]
Brazil_itinerary_df
# Out:
#      City_ID                      City Country  Max Temp  \
# 15        44                    Touros      BR     80.60
# 33        99                  Cidreira      BR     75.97
# 46       127  Sao Jose Da Coroa Grande      BR     78.35
# 53       147          Senador Guiomard      BR     84.20
# 61       170                Vila Velha      BR     80.60
# 62       172           Arraial Do Cabo      BR     78.80
# 67       184                 Caravelas      BR     76.55
# 78       224                Rio Grande      BR     78.80
# 83       245                    Itaqui      BR     76.64
# 87       260                  Belmonte      BR     78.80
# 98       292                Esmeraldas      BR     80.60
# 102      307         Sao Joao Da Barra      BR     77.85
# 113      347                 Boa Vista      BR     86.00
# 114      349                    Labrea      BR     77.18
# 130      405                  Tarauaca      BR     71.94
# 134      416                  Miracema      BR     76.48
# 142      440                  Sao Luis      BR     82.40
# 144      447            Sena Madureira      BR     73.56
# 145      449                    Manaus      BR     82.40
# 146      451                     Natal      BR     80.60
# 147      452          Sao Luiz Gonzaga      BR     71.29
# 148      460                  Cabedelo      BR     80.60
# 175      530                Monte Azul      BR     77.27
# 187      570                     Conde      BR     80.60
# 189      575                    Urucui      BR     79.02
# 193      584                    Assare      BR     75.45
# 199      608           America Dourada      BR     72.54
# 201      614                  Maragogi      BR     77.88
# 202      622        Sao Felix Do Xingu      BR     74.84
# 204      628                  Imbituba      BR     78.80
# 208      641                     Jales      BR     73.53
# 211      647                    Olinda      BR     80.60
# 222      672               Cassilandia      BR     76.69
#
#       Weather Description      Lat      Lng  \
# 15             few clouds  -5.1989 -35.4608
# 33   heavy intensity rain -30.1811 -50.2056
# 46          broken clouds  -8.8978 -35.1478
# 53             few clouds -10.1522 -67.7392
# 61       scattered clouds -20.3297 -40.2925
# 62              clear sky -22.9661 -42.0278
# 67        overcast clouds -17.7125 -39.2481
# 78          moderate rain -32.0350 -52.0986
# 83       scattered clouds -29.1253 -56.5531
# 87             few clouds -15.8631 -38.8828
# 98              clear sky -19.7625 -44.3139
# 102       overcast clouds -21.6403 -41.0511
# 113            few clouds   2.8197 -60.6733
# 114         broken clouds  -7.2586 -64.7981
# 130       overcast clouds  -8.1614 -70.7656
# 134       overcast clouds -21.4122 -42.1967
# 142            light rain  -2.5297 -44.3028
# 144  heavy intensity rain  -9.0656 -68.6569
# 145             clear sky  -3.1019 -60.0250
# 146      scattered clouds  -5.7950 -35.2094
# 147         broken clouds -28.4083 -54.9608
# 148            few clouds  -6.9811 -34.8339
# 175      scattered clouds -15.1550 -42.8747
# 187            few clouds  -7.2597 -34.9075
# 189         broken clouds  -7.2294 -44.5561
# 193       overcast clouds  -6.8744 -39.8750
# 199       overcast clouds -11.4553 -41.4361
# 201         broken clouds  -9.0122 -35.2225
# 202            few clouds  -6.6447 -51.9950
# 204      scattered clouds -28.2400 -48.6703
# 208         moderate rain -20.2689 -50.5458
# 211         broken clouds  -8.0089 -34.8553
# 222         moderate rain -19.1133 -51.7342
#
#                                    Hotel Name
# 15                            INN NEW HORIZON
# 33                              Hotel Castelo
# 46                           Crôa Mares Hotel
# 53                              Paraíso Hotel
# 61                       Hotel Vitória Palace
# 62                        Pousada Porto Praia
# 67                     Pousada dos Navegantes
# 78                 Hotel Atlântico Rio Grande
# 83                                      Biasi
# 87                Pousada Monte Carmelo O Pão
# 98             Bom Será - Marcinho e Fernanda
# 102                   Pousada Porto De Canoas
# 113                        Aipana Plaza Hotel
# 114                      Hotel Novo Horizonte
# 130                            Flat Temporada
# 134                       Novo Hotel Varandas
# 142                               Green Hotel
# 144                             Hotel Central
# 145                            Hotel do Largo
# 146                  Villa Park Hotel | Natal
# 147                              Xerife Hotel
# 148                             Hotel Pigalle
# 175                             Hotel Delfino
# 187                        Pousada Beija Flor
# 189                       Hotel Premium Piauí
# 193                    José Xavier de Andrade
# 199                          Pousada do Ninho
# 201  Salinas do Maragogi All Inclusive Resort
# 202                         Rio Xingu Camping
# 204                      Praia Hotel Imbituba
# 208                   Geraldelli Center Hotel
# 211                  Flat Quatro Rodas Olinda
# 222                    Hotel Rafa Cassilândia

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Weather Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
vacation_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=vacation_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df['City'] == 'Touros']
vacation_end = vacation_df.loc[vacation_df['City'] == 'Touros']
vacation_stop1 = vacation_df.loc[vacation_df['City'] =='Vila Velha']
vacation_stop2 = vacation_df.loc[vacation_df['City']=='Caravelas'] 
vacation_stop3 = vacation_df.loc[vacation_df['City']=='Belmonte']

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
import numpy
start = vacation_start.iloc[0,5:7].to_numpy()
end = vacation_end.iloc[0,5:7].to_numpy()
stop1 = vacation_stop1.iloc[0,5:7].to_numpy()
stop2 = vacation_stop2.iloc[0,5:7].to_numpy()
stop3 = vacation_stop3.iloc[0,5:7].to_numpy()

stop1
# Out:
# array([-20.3297, -40.2925], dtype=object)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".


fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

direction_layer = gmaps.directions_layer(start, end, waypoints = [stop1, stop2, stop3], travel_mode = "DRIVING") 
fig.add_layer(direction_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID        City Country  Max Temp Weather Description      Lat  \
# 0       44      Touros      BR     80.60          few clouds  -5.1989
# 1      170  Vila Velha      BR     80.60    scattered clouds -20.3297
# 2      184   Caravelas      BR     76.55     overcast clouds -17.7125
# 3      260    Belmonte      BR     78.80          few clouds -15.8631
#
#        Lng                   Hotel Name
# 0 -35.4608              INN NEW HORIZON
# 1 -40.2925         Hotel Vitória Palace
# 2 -39.2481       Pousada dos Navegantes
# 3 -38.8828  Pousada Monte Carmelo O Pão

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Weather Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
vacation_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

marker_layer = gmaps.marker_layer(locations, info_box_content=vacation_info)
direction_layer = gmaps.directions_layer(start, end, waypoints = [stop1, stop2, stop3], travel_mode = "DRIVING") 

fig.add_layer(marker_layer)
fig.add_layer(direction_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
